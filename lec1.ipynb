# %% [markdown]
# print function

# %%
print("hello world")
# Out:
# hello world

# %% [markdown]
# vaiables

# %%
course_name = "machine learning"
print(type(course_name))
student_number = 3
print(type(student_number))
rating = 3.2
is_active = True
# Out:
# <class 'str'>
# <class 'int'>

# %% [markdown]
# variable names

# %%
#python roles:(no space, start with charachter or Underscore , no Reserved Words )
#PEP8 roles:( descriptive variable , Small letters varible , space between variable and = and the value)

# %% [markdown]
# string

# %%
course ='python course'
course ="python course"
message = """
hi
hi
hi"""

print(len(course))
# print(course[2])
# print(course[12])
# print(course[-1])
print(course[0:3])
print(course[0:6])
print(course[0:])
print(course[:3])
print(course[:])
# Out:
# 13
# pyt
# python
# python course
# pyt
# python course

# %% [markdown]
# Escape sequences

# %%
#\"
#\'
#\\
#\n
course = "python \"course"
course = 'python \'course'
course = "python \\course"
course = "python \ncourse"



print(course)
# Out:
# python
# course

# %% [markdown]
# Formated string

# %%
first = "christina"
last = "haddad"
full = first + " " + last
print(full)
print(f"first: {first}  last :{last}")
# Out:
# christina haddad
# first: christina  last :haddad

# %% [markdown]
# srting methodes

# %%
course_name = "machine learning"
print(course_name)
print(course_name.upper())
print(course_name.lower())
print(course_name.title())
print(course_name.capitalize())
print(course_name.find("c"))
print(course_name.replace("e","l"))
print("mic" in course_name)
# Out:
# machine learning
# MACHINE LEARNING
# machine learning
# Machine Learning
# Machine learning
# 2
# machinl llarning
# False

# %% [markdown]
# numbers

# %%
print(10+3)
print(10-3)
print(10*3)
print(10/3)
print(10//3)
print(10%3)
print(10**3)


x = 10
x = x + 3
x += 3
# Out:
# 13
# 7
# 30
# 3.3333333333333335
# 3
# 1
# 1000

# %% [markdown]
# working with numbers

# %%
print(round(2.9))
print(abs(-1))

import math
# Out:
# 3
# 1

# %% [markdown]
# Type convertion

# %%
x = input("x: ")
print(type(x))
y = int(x)+1
print(y)
# Out:
# x:  2
# <class 'str'>
# 3

# %%
#str(x)
#float(x)
#bool(x)
#int(x)

# %%
#falsy 
#0
#""
#None

# %%
print(bool("False"))
print(bool(""))
# Out:
# True
# False

# %%
print(bool(0))
# Out:
# False

# %%
print(bool(None))
# Out:
# False
